# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
red_df = pd.read_csv('winequality-red.csv', delimiter=';')
red_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
final_df = red_df

# %%
final_df.shape, final_df['quality'].unique()
# Out:
# ((1599, 12), array([5, 6, 7, 4, 8, 3], dtype=int64))

# %%
final_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
final_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
final_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ## Correlation

# %%
final_df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.heatmap(final_df.corr(), annot = True, fmt = '1.2f', cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## EDA + Feature Selection

# %%
features = []

# %% [markdown]
# ### fixed acidity

# %%
sns.barplot(x='quality', y='fixed acidity', data = final_df);

# %% [markdown]
# - Here all the values for each quality is somewhat is similar
# - it correlation is negative but good

# %%
sns.distplot(final_df['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(final_df[final_df['fixed acidity'] < 12]['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
final_df = final_df[final_df['fixed acidity'] < 12]

# %%
features.append('fixed acidity')

# %% [markdown]
# ### Volatile acidity

# %%
sns.barplot(x='quality', y='volatile acidity', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# - It is highly negatively co-relating with the quality
# - Quality 3 has a lot of variations

# %%
sns.distplot(final_df['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(final_df[final_df['volatile acidity'] < 1.0]['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
final_df = final_df[final_df['volatile acidity'] < 1.0]

# %%
features.append('volatile acidity')

# %% [markdown]
# ### Citric acid

# %%
sns.barplot(x='quality', y='citric acid', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# - It is somewhat correlating with quality but 3 and 9 have more variation
# - Let's check for distribution

# %%
sns.distplot(final_df['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %% [markdown]
# - It is a little left-skewed
# - If we remove the data whose citric acid value is more than 1 then it wiil become normal distribution

# %%
sns.distplot(final_df[final_df['citric acid'] <= 1]['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
final_df = final_df[final_df['citric acid'] <= 1]

# %%
final_df.shape
# Out:
# (1509, 12)

# %%
features.append('citric acid')

# %% [markdown]
# ### Residual sugar

# %%
sns.barplot(x ='quality', y='residual sugar', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %% [markdown]
# - There is no any relation between the quality
# - Let's check for distribution

# %%
sns.distplot(final_df['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %% [markdown]
# - It is highly skewed data so leave it.

# %%
final_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ### Chlorides

# %%
sns.barplot(x='quality', y = 'chlorides', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %% [markdown]
# - Here quality of wine is inversely proportional to chlorine
# - Quality 4 is kind of exceptional
# - It is negatively correlatin but 3 has a lot of variation

# %%
sns.distplot(final_df['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(final_df[final_df['chlorides'] < 0.2 ]['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.barplot(x='quality', y = 'chlorides', data = final_df[final_df['chlorides'] < 0.2 ])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %%
final_df = final_df[final_df['chlorides'] < 0.2 ]

# %%
features.append('chlorides')

# %% [markdown]
# ### Free Sulfur Dioxide

# %%
sns.barplot(x='quality', y='free sulfur dioxide', data = final_df);

# %% [markdown]
# - Here it is a little bit relating with quality but
# - Quality 3 has a lot of variation

# %%
sns.distplot(final_df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(final_df[final_df['free sulfur dioxide']<50 ]['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.barplot(x='quality', y='free sulfur dioxide', data = final_df[final_df['free sulfur dioxide']<50 ])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %% [markdown]
# - Now it is looking good

# %%
features
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'chlorides']

# %% [markdown]
# ### total sulfur dioxide

# %%
sns.barplot(x='quality', y='total sulfur dioxide', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %% [markdown]
# - Here firslty increasing and decreasing kind of plot

# %% [markdown]
# ### Density

# %%
sns.barplot(x='quality', y='density', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %% [markdown]
# - O oo It is not much explainable

# %% [markdown]
# ### pH

# %%
sns.barplot(x='quality', y='pH', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %% [markdown]
# * It is showing very low amount of correlation
# * Let's keep it in features

# %%
features.append('pH')

# %%
final_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ### Sulphates

# %%
sns.barplot(x='quality', y='sulphates', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %% [markdown]
# * Here is good correlation between the data and quality

# %%
sns.distplot(final_df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.barplot(x='quality', y='sulphates', data = final_df[final_df['sulphates'] < 1.25])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
final_df = final_df[final_df['sulphates'] < 1.25]

# %%
features.append('sulphates')

# %% [markdown]
# ### Alcohol

# %%
sns.barplot(x='quality', y='alcohol', data = final_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# - Here is linearly correlating with quality except 3 and 4
# - so  let's check for distribution

# %%
sns.distplot(final_df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# - It is not much skewed but good
# - So it will be considered as features

# %%
features.append('alcohol')
features.append('quality')

# %%
features
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'chlorides',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
len(features)
# Out:
# 8

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
df = red_df[features]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot = True, fmt = '1.2f')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['quality', 'fixed acidity', 'pH'], axis = 1)
y = df['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
train_pred = lr.predict(X_train)
test_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
print( "RMSE of train data: ", mean_squared_error(y_train, train_pred) ** 0.5)
# Out:
# RMSE of train data:  0.6546989431159896

# %%
print( "RMSE of train data: ", mean_squared_error(y_test, test_pred) ** 0.5)
# Out:
# RMSE of train data:  0.6542297283399414

# %%
r = np.round(test_pred)

# %%
np.unique(r)
# Out:
# array([4., 5., 6., 7.])

# %%
final_df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
ll = LogisticRegression(multi_class='multinomial' )
ll.fit(X_train, y_train)
ll.score(X_train, y_train)
# Out:
# 0.5770132916340891

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, ll.predict(X_test))
# Out:
# array([[  0,   0,   3,   0,   0,   0],
#        [  0,   0,   5,   3,   0,   0],
#        [  0,   0, 111,  34,   1,   0],
#        [  0,   0,  41,  65,  10,   0],
#        [  0,   0,   3,  27,  12,   0],
#        [  0,   0,   0,   3,   2,   0]], dtype=int64)
